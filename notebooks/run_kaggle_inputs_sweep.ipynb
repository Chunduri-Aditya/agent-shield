# %% [markdown]
# # Agent Shield Kaggle inputs/ sweep
#
# Run this from a Kaggle Benchmarks notebook so `kaggle_benchmarks` can use Kaggle's free model proxy.

# %%
import os
from pathlib import Path

repo = Path('/kaggle/working/agent-shield')
if not repo.exists():
    # !git clone https://github.com/Chunduri-Aditya/agent-shield.git /kaggle/working/agent-shield
os.chdir(repo)
print(Path.cwd())

# %%
# Comma-separated Kaggle Benchmarks model IDs.
# Adjust this list to whatever your Kaggle model panel/token allows.
os.environ['KAGGLE_MODELS'] = ','.join([
    'google/gemini-2.5-flash',
    'anthropic/claude-sonnet-4',
    'meta/llama-3.1-70b',
])

# %%
# !python scripts/kaggle_inputs_runner.py

# %%
print(Path('logs/kaggle_inputs_rows.md').read_text())
